# %% [markdown]
# Feature Engineering

# %%
print("1.Missing values imputation")
print("2.Handling categorial values")
print("3.Outliner Detection")
print("4.Feature Scaling")
print("5.Feature construction")
print("6.Feature selection")
print("7.Feature selection")
# Out:
# 1.Missing values imputation
# 2.Handling categorial values
# 3.Outliner Detection
# 4.Feature Scaling
# 5.Feature construction
# 6.Feature selection
# 7.Feature selection
